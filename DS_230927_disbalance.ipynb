# %% [markdown]
# # 1. Вводный ликбез
# 1. Anaconda (в принципе, что она просто должна быть + для открытия Джупитера + вызов командной строки для установки некоторых библиотек)
# 2. Jupyter notebook (пространство с файлами, работа из папок, создание документов, запущенные коды)
# 3. Скрипт: файл, сохранение скрипта, сохранение и редактирование файла, правила написания кода (1 функция - один чанк, все загружаемые библиотеки - вверху в одном блоке, комментарии, заголовки - с помощью разметки Markdown)
# 4. Markdown разметка
# 5. Правила формулировки вопросов: решаемая задача -> ПО (тип ОС, версия Python, загруженные библиотеки)-> код с комментариями -> данные -> вывод результата -> ссылки на найденные решения и пояснения, почему они не сработали
# 6. Правила называния файлов: только латинница, без пробелов.
# 7. Version control: Github (только если сами разбираетесь в нем!). В ином случае: отдельная папка под проект, файл скрипта: script_name_NNNN_YYMMDD_0N, где NNNN - первые буквы фамилий участников, YYMMDD - последние 2 цифры текущего года, месяц, день (например, 230901 - версия скрипта от 1 сентября 2023 года). Последняя цифра - опциональна, нужно, только если у вас возникло несколько версий за один день, последняя буква - фамилия автора версии

# %% [markdown]
# ## 1.4. Markdown
#
# # Первый уровень — название проекта
# ## Второй уровень — разделы проекта
# ### Третий уровень - подразделы проекта
#
# 1. нумерованный
# 2. список
# 3. довольно
# 4. очевиден.
#
#
# - Многоуровневый
#  - список
#   - списочков
#
#
# * просто список
# * буллитами
#
#
# *Курсив*
#
# **Полужирный**
#
# ***Полужирный курсив***
#
#
# Выделять `текст` можно еще и так.
#
# [Подробнее о Markdown по ссылке](https://daringfireball.net/projects/markdown/)
#
# [Проще о Markdown по другой ссылке](https://gist.github.com/Jekins/2bf2d0638163f1294637)

# %% [markdown]
# ## 1.6. Загрузка библиотек в Python

# %%
# загрузить библиотеку с удобным сокращенным названием
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

# иногда нужно прицельно загружать отдельные элементы из библиотеки, общей пачкой они не подгружаются, 
# либо это необходимо, чтобы не возникало конфликта между библиотеками
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import cross_val_score, GridSearchCV

# это можно делать через запятую:
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

# иногда библиотеку нельзя установить сразу через импорт, нужен pip:
#pip install
#!pip install имя_библиотеки -U 
#import имя_библиотеки

# не работает pip? нужно идти в командную строку и stackoverflow

import seaborn as sns

# %% [markdown]
# ## 1.7. Чтение файлов в Python

# %%
# Читаем файл *music_project.csv* и сохраним его в переменной *df*: 
df = pd.read_csv('C:/Users/m42al/Downloads/Global YouTube Statistics.csv', sep=";")

# %% [markdown]
# # 2. Изучение данных и предобработка

# %%
# Получение первых 5 строк таблицы

df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
# для отображения всех столбцов

pd.set_option('display.max_columns', None)

# %%
# Получение первых 10 строк таблицы

df.head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ��� Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# ...

# %%
# Получение последних 5 строк таблицы

df.tail()
# Out:
#       rank                  Youtuber  subscribers   video views  \
# 1063   991              Natan por A�     12300000  9.029610e+09
# 1064   992  Free Fire India Official     12300000  1.674410e+09
# 1065   993                     Panda     12300000  2.214684e+09
# 1066   994               RobTopGames     12300000  3.741235e+08
# 1067   995              Make Joke Of     12300000  2.129774e+09
#
#             category                     Title  uploads         Country  \
# 1063          Sports              Natan por A�     1200          Brazil
# 1064  People & Blogs  Free Fire India Official     1500           India
# 1065             NaN               HybridPanda     2452  United Kingdom
# 1066          Gaming               RobTopGames       39          Sweden
# 1067          Comedy              Make Joke Of       62           India
#
#      Abbreviation   channel_type  video_views_rank  country_rank  \
# 1063           BR  Entertainment             525.0          55.0
# ...

# %%
# Получение последних 10 строк таблицы

df.tail(10)
# Out:
#       rank                  Youtuber  subscribers   video views  \
# 1058   986                      TKOR     12400000  3.392023e+09
# 1059   987                 ANNA KOVA     12400000  1.395959e+10
# 1060   988             Avril Lavigne     12400000  6.202090e+09
# 1061   989                    Caylus     12400000  4.779140e+09
# 1062   990                 Migos ATL     12400000  6.993406e+09
# 1063   991              Natan por A�     12300000  9.029610e+09
# 1064   992  Free Fire India Official     12300000  1.674410e+09
# 1065   993                     Panda     12300000  2.214684e+09
# 1066   994               RobTopGames     12300000  3.741235e+08
# 1067   995              Make Joke Of     12300000  2.129774e+09
#
#             category                     Title  uploads         Country  \
# 1058       Education                      TKoR        0             NaN
# 1059  People & Blogs                  annakova        1             NaN
# ...

# %%
# Общая информация о данных таблицы df

df.info()
# Опишите таблицу. Стоит обращать внимание на: типы переменных, пропуски, соответствие типов переменных 
# содержащимся данным (это соотнести с отображенными таблицами), заголовки столбцов. Какие проблемы в данных можно 
# заметить на этом этапе?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     1068 non-null   int64
#  1   Youtuber                                 1068 non-null   object
#  2   subscribers                              1068 non-null   int64
#  3   video views                              1068 non-null   float64
#  4   category                                 1015 non-null   object
#  5   Title                                    1068 non-null   object
#  6   uploads                                  1068 non-null   int64
#  7   Country                                  936 non-null    object
#  8   Abbreviation                             936 non-null    object
#  9   channel_type                             1036 non-null   object
# ...

# %% [markdown]
# ## 2.1. Проблема со столбцами?

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# у нас есть заголовки столбцов, которые начинаются с пробелов. Это некрасиво и может затруднять дальнейшую работу, 
# удалим их

# %%
# <переименование столбцов>
new_names = ['rank', 'youtuber_name', 'subscribers', 'video_views', 'category', 'title', 'uploads', 'country', 
             'country_abbreviation', 'channel_type', 'video_views_rank', 'country_rank', 'channel_type_rank', 
             'video_views_for_the_last_30_days', 'lowest_monthly_earnings', 'highest_monthly_earnings', 
             'lowest_yearly_earnings', 'highest_yearly_earnings', 'subscribers_for_last_30_days', 'created_year', 
             'created_month', 'created_date', 'gross_tertiary_education_enrollment_percent', 'population', 
             'unemployment_rate', 'urban_population', 'latitude', 'longitude']
df.set_axis(new_names, axis = 'columns', inplace = True)

# %%
# проверка результатов - перечень заголовков столбцов
print(df.columns)
# Out:
# Index(['rank', 'youtuber_name', 'subscribers', 'video_views', 'category',
#        'title', 'uploads', 'country', 'country_abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'gross_tertiary_education_enrollment_percent', 'population',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## 2.2 Проблема с дубликатами?

# %%
# Необходимо установить наличие дубликатов. Если найдутся, удаляем, и проверяем, все ли удалились.
# <получение суммарного количества дубликатов в таблице df>
print(df.duplicated().sum())
# Out:
# 73

# %%
# <удаление всех дубликатов из таблицы
df = df.drop_duplicates().reset_index(drop=True)

# %%
# <проверка на отсутствие>
print(df.duplicated().sum())
# Out:
# 0

# %%
# <получение общей информации о данных таблицы df>
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   rank                                         995 non-null    int64
#  1   youtuber_name                                995 non-null    object
#  2   subscribers                                  995 non-null    int64
#  3   video_views                                  995 non-null    float64
#  4   category                                     949 non-null    object
#  5   title                                        995 non-null    object
#  6   uploads                                      995 non-null    int64
#  7   country                                      873 non-null    object
#  8   country_abbreviation                         873 non-null    object
# ...

# %% [markdown]
# ## 2.3. Проблема с пропусками?

# %%
# общее число пропусков по всем переменным, выявленных методом isnull() в таблице df
df.isnull().sum()
# Все пропуски необходимо как-то обработать: либо удалить, либо заполнить (второе - более предпочтительно в DS)
# Out:
# rank                                             0
# youtuber_name                                    0
# subscribers                                      0
# video_views                                      0
# category                                        46
# title                                            0
# uploads                                          0
# country                                        122
# country_abbreviation                           122
# channel_type                                    30
# video_views_rank                                 1
# country_rank                                   116
# channel_type_rank                               33
# video_views_for_the_last_30_days                56
# lowest_monthly_earnings                          0
# highest_monthly_earnings                         0
# lowest_yearly_earnings                           0
# highest_yearly_earnings                          0
# ...

# %%
df.head()
# Out:
#    rank               youtuber_name  subscribers   video_views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       title  uploads        country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   country_abbreviation   channel_type  video_views_rank  country_rank  \
# 0                   IN          Music               1.0           1.0
# ...

# %%
df[df['country_abbreviation'].isnull()].head()
# Out:
#     rank                                      youtuber_name  subscribers  \
# 5      6                                              Music    119000000
# 12    13                                             Gaming     93600000
# 14    15                                          Goldmines     86900000
# 38    39  LooLoo Kids - Nursery Rhymes and Children's Songs     54000000
# 48    49                                            Badabun     46800000
#
#      video_views          category  \
# 5   0.000000e+00               NaN
# 12  0.000000e+00               NaN
# 14  2.411823e+10  Film & Animation
# 38  3.231243e+10             Music
# 48  1.939805e+10     Entertainment
#
#                                             title  uploads country  \
# 5                                           Music        0     NaN
# 12                                         Gaming        0     NaN
# 14                                      goldmines        1     NaN
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df = df.dropna(subset=['country_abbreviation'])

# %%
df[df['category'].isnull()].head(15)
# Out:
#      rank                              youtuber_name  subscribers  \
# 18     19                                     Sports     75000000
# 91     92                                  Vlad v���     37900000
# 132   133                                  BETER B��     32700000
# 155   156                         Diana and Roma ESP     30700000
# 161   162  ��������������� ������ ������������������     30400000
# 214   215                                 D Billions     26200000
# 255   256                            shfa show India     24200000
# 256   257   Super JoJo - Nursery Rhymes & Kids Songs     24100000
# 261   262                         Diana and Roma ARA     24100000
# 312   313                       Vlad and Niki Arabic     22500000
# 319   320                          Vlad and Niki ESP     22000000
# 332   333                 ZAMZAM ELECTRONICS TRADING     21700000
# 355   356                          Vlad and Niki IDN     21000000
# ...

# %%
df['category'].unique()
# Out:
# array(['Music', 'Film & Animation', 'Entertainment', 'Education', 'Shows',
#        'People & Blogs', 'Gaming', 'Sports', 'Howto & Style', nan,
#        'News & Politics', 'Comedy', 'Trailers', 'Nonprofits & Activism',
#        'Science & Technology', 'Movies', 'Pets & Animals',
#        'Autos & Vehicles', 'Travel & Events'], dtype=object)

# %%
df['channel_type'].unique()
# Out:
# array(['Music', 'Games', 'Entertainment', 'Education', 'People', 'Sports',
#        'Film', 'News', 'Comedy', 'Howto', 'Nonprofit', 'Tech', nan,
#        'Animals', 'Autos'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   rank                                         873 non-null    int64
#  1   youtuber_name                                873 non-null    object
#  2   subscribers                                  873 non-null    int64
#  3   video_views                                  873 non-null    float64
#  4   category                                     834 non-null    object
#  5   title                                        873 non-null    object
#  6   uploads                                      873 non-null    int64
#  7   country                                      873 non-null    object
#  8   country_abbreviation                         873 non-null    object
# ...

# %%
df.loc[df.channel_type == 'Games', 'category'] = 'Gaming'
df.loc[df.channel_type == 'Entertainment', 'category'] = 'Entertainment'
df.loc[df.channel_type == 'Music', 'category'] = 'Music'
df.loc[df.channel_type == 'Sports', 'category'] = 'Sports'
df.loc[df.channel_type == 'Education', 'category'] = 'Education'
df.loc[df.channel_type == 'People', 'category'] = 'People & Blogs'
df.loc[df.channel_type == 'Howto', 'category'] = 'Howto & Style'
df.loc[df.channel_type == 'Tech', 'category'] = 'Science & Technology'

# %%
# <удаление пропущенных значений в столбце 'genre_name'>
df = df.dropna(subset=['category'])

# %%
df[df['channel_type'].isnull()].head(15)
# Out:
#      rank       youtuber_name  subscribers   video_views  \
# 190   191  Sandeep Maheshwari     27800000  2.303069e+09
# 340   341                YOLO     21400000  1.573059e+09
# 508   509  The Game Theorists     17600000  3.752347e+09
# 555   556  IDEAS EN 5 MINUTOS     16600000  3.696973e+09
# 853   854  Blockbuster Movies     13400000  2.650061e+09
# 904   905     Jomy Production     13000000  5.057163e+09
# 969   970     Quantum Tech HD     12500000  4.340213e+09
#
#                  category               title  uploads    country  \
# 190        People & Blogs   Sandeepmaheshwari        0  Singapore
# 340                Comedy                YOLO        0    Germany
# 508                Gaming    TheGameTheorists        0  Australia
# 555         Howto & Style  Ideas En 5 Minutos      216      Spain
# 853         Entertainment  Blockbuster Movies        0      India
# 904         Entertainment       SRK Edie soon        8      India
# ...

# %%
df.loc[df.category == 'People & Blogs', 'channel_type'] = 'People'
df.loc[df.category == 'Howto & Style', 'channel_type'] = 'Howto'
df.loc[df.category == 'Entertainment', 'channel_type'] = 'Entertainment'
df.loc[df.category == 'Science & Technology', 'channel_type'] = 'Tech'
df.loc[df.category == 'Comedy', 'channel_type'] = 'Comedy'
df.loc[df.category == 'Gaming', 'channel_type'] = 'Games'

# %%
df[df['video_views_rank'].isnull()].head(15)
# Out:
#      rank youtuber_name  subscribers   video_views category        title  \
# 735   736  LEGENDA FUNK     14500000  2.440718e+09    Music  LegendaFUNK
#
#      uploads country country_abbreviation channel_type  video_views_rank  \
# 735        0  Brazil                   BR        Music               NaN
#
#      country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# 735           NaN                NaN                               NaN
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 735                      0.0                       0.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  \
# 735                     0.0                      0.0
#
#      subscribers_for_last_30_days  created_year created_month  created_date  \
# 735                           NaN           NaN           NaN           NaN
#
#      gross_tertiary_education_enrollment_percent   population  \
# 735                                         51.3  212559417.0
#
# ...

# %%
df[639:640] = df[639:640].fillna(0)

# %%
df[df['video_views_rank'].isnull()].head(15)
# Out:
# Empty DataFrame
# Columns: [rank, youtuber_name, subscribers, video_views, category, title, uploads, country, country_abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, gross_tertiary_education_enrollment_percent, population, unemployment_rate, urban_population, latitude, longitude]
# Index: []

# %%
df[639:640]
# Out:
#      rank youtuber_name  subscribers   video_views category        title  \
# 735   736  LEGENDA FUNK     14500000  2.440718e+09    Music  LegendaFUNK
#
#      uploads country country_abbreviation channel_type  video_views_rank  \
# 735        0  Brazil                   BR        Music               0.0
#
#      country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# 735           0.0                0.0                               0.0
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 735                      0.0                       0.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  \
# 735                     0.0                      0.0
#
#      subscribers_for_last_30_days  created_year created_month  created_date  \
# 735                           0.0           0.0             0           0.0
#
#      gross_tertiary_education_enrollment_percent   population  \
# 735                                         51.3  212559417.0
#
# ...

# %%
df[df['channel_type_rank'].isnull()].head(15)
# Out:
#      rank       youtuber_name  subscribers   video_views  \
# 73     74    Luisito Comunica     40600000  8.670474e+09
# 190   191  Sandeep Maheshwari     27800000  2.303069e+09
# 340   341                YOLO     21400000  1.573059e+09
# 508   509  The Game Theorists     17600000  3.752347e+09
# 555   556  IDEAS EN 5 MINUTOS     16600000  3.696973e+09
# 853   854  Blockbuster Movies     13400000  2.650061e+09
# 904   905     Jomy Production     13000000  5.057163e+09
# 969   970     Quantum Tech HD     12500000  4.340213e+09
#
#                  category                     title  uploads    country  \
# 73                 Comedy  Luis Arturo Villar Sudek        0     Mexico
# 190        People & Blogs         Sandeepmaheshwari        0  Singapore
# 340                Comedy                      YOLO        0    Germany
# 508                Gaming          TheGameTheorists        0  Australia
# 555         Howto & Style        Ideas En 5 Minutos      216      Spain
# ...

# %%
df.groupby('channel_type')['channel_type_rank'].mean()
# Out:
# channel_type
# Animals             1.500000
# Autos               1.000000
# Comedy            148.564103
# Education          24.744681
# Entertainment     373.976974
# Film              313.217391
# Games            1031.459770
# Howto              23.531250
# Music             403.056122
# News              177.090909
# Nonprofit           1.500000
# People            918.768293
# Sports            378.500000
# Tech                8.733333
# Name: channel_type_rank, dtype: float64

# %%
df.groupby('channel_type')['channel_type_rank'].median()
# Out:
# channel_type
# Animals            1.5
# Autos              1.0
# Comedy            27.0
# Education         26.0
# Entertainment    123.5
# Film              23.0
# Games             48.0
# Howto             22.5
# Music            103.0
# News              15.5
# Nonprofit          1.5
# People            42.0
# Sports             7.5
# Tech               9.0
# Name: channel_type_rank, dtype: float64

# %%
#создаем сводную таблицу с медианами рангов для каналов разного типа
type_pivot = df.pivot_table(index='channel_type', values='channel_type_rank', aggfunc='median')
type_pivot.set_axis(['channel_type_rank_median'], axis='columns',inplace=True)
#добавляем столбцы медианами
df = df.merge(type_pivot, on = 'channel_type')

# %%
df.head()
# Out:
#    rank      youtuber_name  subscribers   video_views category  \
# 0     1           T-Series    245000000  2.280000e+11    Music
# 1    11  Zee Music Company     96700000  5.785629e+10    Music
# 2    14          BLACKPINK     89800000  3.214460e+10    Music
# 3    18          BANGTANTV     75600000  2.082699e+10    Music
# 4    20      Justin Bieber     71600000  3.060812e+10    Music
#
#                title  uploads      country country_abbreviation channel_type  \
# 0           T-Series    20082        India                   IN        Music
# 1  Zee Music Company     8548        India                   IN        Music
# 2          BLACKPINK      543  South Korea                   KR        Music
# 3          BANGTANTV     2281  South Korea                   KR        Music
# 4      Justin Bieber      249       Canada                   CA        Music
#
#    video_views_rank  country_rank  channel_type_rank  \
# 0               1.0           1.0                1.0
# ...

# %%
#замена пустных значений медианными значениями ранга для тех же типов блогов
df['channel_type_rank'] = df['channel_type_rank'].fillna(df['channel_type_rank_median'])

# %%
df_cp = df.copy()

# %%
df[df['video_views_for_the_last_30_days'].isnull()].head(15)
# Out:
#      rank          youtuber_name  subscribers   video_views       category  \
# 58    218  1MILLION Dance Studio     26100000  7.886440e+09          Music
# 211   274               FaZe Rug     23700000  7.451792e+09         Gaming
# 213   300            Alan Becker     22900000  5.380074e+09         Gaming
# 217   378            Linkin Park     20400000  1.339700e+10         Gaming
# 221   412  Official Pink Panther     19700000  1.095562e+10         Gaming
# 231   509     The Game Theorists     17600000  3.752347e+09         Gaming
# 237   555          Werever2morro     16600000  2.798274e+09         Gaming
# 240   601   La Rosa de Guadalupe     16100000  9.642146e+09         Gaming
# 242   607             ����������     15900000  1.845330e+09         Gaming
# 249   681             TheRichest     15000000  2.730879e+09         Gaming
# 258   763           Harry Styles     14400000  5.689224e+09         Gaming
# ...

# %%
#создаем сводную таблицу с медианами просмотров видео в зависимости от типа канала
video_pivot = df.pivot_table(index='channel_type', values='video_views_for_the_last_30_days', aggfunc='median')
video_pivot.set_axis(['video_views_for_the_last_30_days_median'], axis='columns',inplace=True)
#добавляем столбцы с медианами
df = df.merge(video_pivot, on = 'channel_type')

# %%
#замена пустных значений медианными значениями ранга для тех же типов блогов
df['video_views_for_the_last_30_days'] = df['video_views_for_the_last_30_days'].fillna(df['video_views_for_the_last_30_days_median'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872 entries, 0 to 871
# Data columns (total 30 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   rank                                         872 non-null    int64
#  1   youtuber_name                                872 non-null    object
#  2   subscribers                                  872 non-null    int64
#  3   video_views                                  872 non-null    float64
#  4   category                                     872 non-null    object
#  5   title                                        872 non-null    object
#  6   uploads                                      872 non-null    int64
#  7   country                                      872 non-null    object
#  8   country_abbreviation                         872 non-null    object
# ...

# %%
df[df['subscribers_for_last_30_days'].isnull()].head(15)
# Out:
#     rank               youtuber_name  subscribers   video_views category  \
# 6     24             Canal KondZilla     66500000  3.677559e+10    Music
# 8     28       T-Series Bhakti Sagar     61000000  2.953323e+10    Music
# 31    99                    Maroon 5     36600000  2.255392e+10    Music
# 38   128           NoCopyrightSounds     33400000  1.053073e+10    Music
# 43   149            JustinBieberVEVO     31600000  2.658387e+10    Music
# 45   161                 Trap Nation     30400000  1.403743e+10    Music
# 49   171                Shawn Mendes     30000000  1.283120e+10    Music
# 50   173               Ultra Records     29600000  1.720803e+10    Music
# 52   192  Bounce Patrol - Kids Songs     27800000  2.103785e+10    Music
# 54   194                   MrBeast 2     27500000  4.552581e+09    Music
# 57   210             WORLDSTARHIPHOP     26500000  2.035812e+10    Music
# 58   218       1MILLION Dance Studio     26100000  7.886440e+09    Music
# ...

# %%
#создаем сводную таблицу с медианами числа подписчиков для разного типа каналов
subs_pivot = df.pivot_table(index='channel_type', values='subscribers_for_last_30_days', aggfunc='median')
subs_pivot.set_axis(['subscribers_for_last_30_days_med'], axis='columns',inplace=True)
#добавляем столбцы с медианами
df = df.merge(subs_pivot, on = 'channel_type')

# %%
#замена пустных значений медианными значениями ранга для тех же типов блогов
df['subscribers_for_last_30_days'] = df['subscribers_for_last_30_days'].fillna(df['subscribers_for_last_30_days_med'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872 entries, 0 to 871
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   rank                                         872 non-null    int64
#  1   youtuber_name                                872 non-null    object
#  2   subscribers                                  872 non-null    int64
#  3   video_views                                  872 non-null    float64
#  4   category                                     872 non-null    object
#  5   title                                        872 non-null    object
#  6   uploads                                      872 non-null    int64
#  7   country                                      872 non-null    object
#  8   country_abbreviation                         872 non-null    object
# ...

# %%
df[df['created_year'].isnull()].head(15)
# Out:
#      rank       youtuber_name  subscribers   video_views category  \
# 231   509  The Game Theorists     17600000  3.752347e+09   Gaming
# 258   763        Harry Styles     14400000  5.689224e+09   Gaming
#
#                 title  uploads        country country_abbreviation  \
# 231  TheGameTheorists        0      Australia                   AU
# 258       harrystyles        0  United States                   US
#
#     channel_type  video_views_rank  country_rank  channel_type_rank  \
# 231        Games         3612215.0        6095.0               48.0
# 258        Games         4037956.0        7574.0             7340.0
#
#      video_views_for_the_last_30_days  lowest_monthly_earnings  \
# 231                        44202500.0                      0.0
# 258                        44202500.0                      0.0
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 231                       0.0                     0.0
# ...

# %%
df = df.dropna(subset=['created_year'])

# %%
df[df['gross_tertiary_education_enrollment_percent'].isnull()].head()
# Out:
#      rank youtuber_name  subscribers   video_views        category  \
# 684   664         Musas     15100000  2.400038e+09  People & Blogs
#
#           title  uploads  country country_abbreviation channel_type  \
# 684  Jordi Sala      159  Andorra                   AD       People
#
#      video_views_rank  country_rank  channel_type_rank  \
# 684         3889418.0         504.0             7615.0
#
#      video_views_for_the_last_30_days  lowest_monthly_earnings  \
# 684                              86.0                     0.02
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 684                      0.34                    0.26
#
#      highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# 684                      4.0                      200000.0        2006.0
#
#     created_month  created_date  gross_tertiary_education_enrollment_percent  \
# 684           Mar          12.0                                          NaN
#
# ...

# %%
df.loc[df['country'] == 'Andorra']
# Out:
#      rank youtuber_name  subscribers   video_views        category  \
# 684   664         Musas     15100000  2.400038e+09  People & Blogs
#
#           title  uploads  country country_abbreviation channel_type  \
# 684  Jordi Sala      159  Andorra                   AD       People
#
#      video_views_rank  country_rank  channel_type_rank  \
# 684         3889418.0         504.0             7615.0
#
#      video_views_for_the_last_30_days  lowest_monthly_earnings  \
# 684                              86.0                     0.02
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 684                      0.34                    0.26
#
#      highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# 684                      4.0                      200000.0        2006.0
#
#     created_month  created_date  gross_tertiary_education_enrollment_percent  \
# 684           Mar          12.0                                          NaN
#
# ...

# %%
df = df.dropna(subset=['gross_tertiary_education_enrollment_percent'])

# %%
df = df[df.created_year != 0]

# %%
# <проверка>
df.isnull().sum()
# Out:
# rank                                           0
# youtuber_name                                  0
# subscribers                                    0
# video_views                                    0
# category                                       0
# title                                          0
# uploads                                        0
# country                                        0
# country_abbreviation                           0
# channel_type                                   0
# video_views_rank                               0
# country_rank                                   0
# channel_type_rank                              0
# video_views_for_the_last_30_days               0
# lowest_monthly_earnings                        0
# highest_monthly_earnings                       0
# lowest_yearly_earnings                         0
# highest_yearly_earnings                        0
# subscribers_for_last_30_days                   0
# ...

# %% [markdown]
# ## 2.4 Изменение типов переменных

# %%
# <получение общей информации о данных таблицы df>
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 868 entries, 0 to 871
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   rank                                         868 non-null    int64
#  1   youtuber_name                                868 non-null    object
#  2   subscribers                                  868 non-null    int64
#  3   video_views                                  868 non-null    float64
#  4   category                                     868 non-null    object
#  5   title                                        868 non-null    object
#  6   uploads                                      868 non-null    int64
#  7   country                                      868 non-null    object
#  8   country_abbreviation                         868 non-null    object
# ...

# %%
df.head()
# Out:
#    rank      youtuber_name  subscribers   video_views category  \
# 0     1           T-Series    245000000  2.280000e+11    Music
# 1    11  Zee Music Company     96700000  5.785629e+10    Music
# 2    14          BLACKPINK     89800000  3.214460e+10    Music
# 3    18          BANGTANTV     75600000  2.082699e+10    Music
# 4    20      Justin Bieber     71600000  3.060812e+10    Music
#
#                title  uploads      country country_abbreviation channel_type  \
# 0           T-Series    20082        India                   IN        Music
# 1  Zee Music Company     8548        India                   IN        Music
# 2          BLACKPINK      543  South Korea                   KR        Music
# 3          BANGTANTV     2281  South Korea                   KR        Music
# 4      Justin Bieber      249       Canada                   CA        Music
#
#    video_views_rank  country_rank  channel_type_rank  \
# 0               1.0           1.0                1.0
# ...

# %%
df['uploads'] = df['uploads'].astype(float)

# %%
df['created_date'] = df['created_date'].astype(int)
df['created_year'] = df['created_year'].astype(int)

# %% [markdown]
# # Подготовка к машинному обучению: снова предобработка

# %%
df['country'].unique()
# Out:
# array(['India', 'South Korea', 'Canada', 'Brazil', 'Argentina',
#        'United States', 'United Kingdom', 'Barbados', 'Colombia',
#        'Jordan', 'Netherlands', 'Australia', 'Saudi Arabia', 'Turkey',
#        'Thailand', 'France', 'Mexico', 'Sweden', 'Spain', 'Iraq',
#        'Morocco', 'Philippines', 'Samoa', 'Chile', 'El Salvador',
#        'Afghanistan', 'Indonesia', 'Russia', 'Germany', 'Finland',
#        'Ecuador', 'Japan', 'Pakistan', 'Kuwait', 'Italy', 'Ukraine',
#        'United Arab Emirates', 'Vietnam', 'Malaysia', 'Singapore',
#        'Egypt', 'Peru', 'Bangladesh', 'Cuba', 'Venezuela', 'Switzerland',
#        'Latvia', 'China'], dtype=object)

# %%
def g7(row):
    if row == 'United States':
        return 1
    if row == 'France':
        return 1
    if row == 'Germany':
        return 1
    if row == 'United Kingdom':
        return 1
    if row == 'Canada':
        return 1
    if row == 'Italy':
        return 1
    if row == 'Japan':
        return 1
    return 0

# %%
df['g7_member'] = df['country'].apply(g7)

# %%
df.tail()
# Out:
#      rank     youtuber_name  subscribers   video_views              category  \
# 867   885   Technology Gyan     13200000  1.138262e+09  Science & Technology
# 868   970   Quantum Tech HD     12500000  4.340213e+09  Science & Technology
# 869   276  That Little Puff     23700000  2.028969e+10        Pets & Animals
# 870   359  Brave Wilderness     20900000  4.927879e+09        Pets & Animals
# 871   787  Supercar Blondie     14100000  5.405563e+09      Autos & Vehicles
#
#                  title  uploads               country country_abbreviation  \
# 867    Technology Gyan   1022.0                 India                   IN
# 868  Mr_Mughall Gaming    223.0              Pakistan                   PK
# 869   That Little Puff    769.0         United States                   US
# 870   Brave Wilderness    982.0         United States                   US
# 871   Supercar Blondie    855.0  United Arab Emirates                   AE
#
# ...

# %% [markdown]
# #### Делаем дисбаланс классов в данных

# %%
print(df['g7_member'].value_counts())
# Out:
# 0    481
# 1    232
# Name: g7_member, dtype: int64

# %%
# удалим столбцы, которые нам не понадобятся для исследовательской целей
df = df.drop(['rank','latitude','longitude','country_abbreviation','title', 'youtuber_name', 'country'], axis=1)

# %%
df_copy = df.copy()

# %%
df = df.drop(df.query('g7_member > 0').sample(frac=.4).index)

# %% [markdown]
# #### Продолжаем подготовку данных

# %%
# Перекодируем категориальные признаки с помощью OHE
df_ohe = pd.get_dummies(df, drop_first=True)

# %%
# отделяем предикторы от зависимой переменной
features = df_ohe.drop(['g7_member'], axis=1)
target = df_ohe['g7_member']

# разбиваем на тестовую и обучающую подвыборки
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.3, random_state=42)

print('Размер обучающей выборки с признаками:', features_train.shape[0])
print('Размер обучающей выборки с у:',target_train.shape[0])
print('Размер тестовой выборки с признаками:',features_test.shape[0])
print('Размер тестовой выборки с у:',target_test.shape[0])
# Out:
# Размер обучающей выборки с признаками: 499
# Размер обучающей выборки с у: 499
# Размер тестовой выборки с признаками: 214
# Размер тестовой выборки с у: 214

# %%
target_pred_constant = pd.Series(0, index = target.index)
print(accuracy_score(target, target_pred_constant))
# Out:
# 0.6746143057503506

# %%
class_frequency = df_ohe['g7_member'].value_counts(normalize=True)
print(class_frequency)
class_frequency.plot(kind='bar')
# Out:
# 0    0.674614
# 1    0.325386
# Name: g7_member, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# #  Модели классификации: борьба с дисбалансом 1 (Взвешивание классов)

# %%
model_reg = LogisticRegression(random_state=12345, solver='liblinear')
model_reg.fit(features_train, target_train)
predictions = model_reg.predict(features_test)
print(classification_report(target_test, predictions))
confusion_matrix(target_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       147
#            1       0.77      0.81      0.79        67
#
#     accuracy                           0.86       214
#    macro avg       0.84      0.85      0.84       214
# weighted avg       0.87      0.86      0.87       214
# array([[131,  16],
#        [ 13,  54]], dtype=int64)

# %%
model_reg = LogisticRegression(random_state=12345, solver='liblinear', class_weight='balanced')
model_reg.fit(features_train, target_train)
predictions = model_reg.predict(features_test)
print(classification_report(target_test, predictions))
confusion_matrix(target_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       147
#            1       0.72      0.84      0.77        67
#
#     accuracy                           0.85       214
#    macro avg       0.82      0.84      0.83       214
# weighted avg       0.86      0.85      0.85       214
# array([[125,  22],
#        [ 11,  56]], dtype=int64)

# %% [markdown]
# #  Модели классификации: борьба с дисбалансом 2 (Увеличение выбоки)

# %%
from sklearn.utils import shuffle

# %% [markdown]
# **1**
#
# Мы разделили обучающую выборку на отрицательные и положительные объекты.
# Объявите четыре переменные и запишите в них:
# - features_zeros — признаки объектов с ответом «0»;
# - features_ones — признаки объектов с ответом «1»;
# - target_zeros — целевой признак объектов, у которых ответы только «0»;
# - target_ones — целевой признак объектов, у которых ответы только «1».
# Напечатайте на экране размеры таблиц, которые хранятся в четырёх переменных (уже в прекоде).

# %%
features_zeros = features_train[target_train == 0]
features_ones = features_train[target_train == 1]
target_zeros = target_train[target_train == 0]
target_ones = target_train[target_train == 1]

print(features_zeros.shape)
print(features_ones.shape)
print(target_zeros.shape)
print(target_ones.shape)
# Out:
# (334, 60)
# (165, 60)
# (334,)
# (165,)

# %% [markdown]
# **2**
#
# Продублируйте объекты положительного класса и объедините их с объектами отрицательного класса. Чтобы соединить таблицы, воспользуйтесь функцией pd.concat().
#
# Мы объединили таблицы с признаками и сохранили результат в переменной features_upsampled (признаки, преобразованные техникой upsampling). Сделайте то же самое для целевого признака и объявите переменную target_upsampled (целевой признак, преобразованный техникой upsampling).
#
# Количество повторений уже сохранено в переменной repeat (англ. «повторять»).
#
# Напечатайте на экране размеры новых переменных (в прекоде).

# %%
repeat = 10

features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat) 
print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (1984, 60)
# (1984,)

# %% [markdown]
# **3**
#
# Перемешайте данные. Импортируйте функцию shuffle() (англ. «перетасовать») из модуля sklearn.utils (от англ. «утилиты»).
# Создайте функцию upsample() с тремя параметрами:
# - features — признаки,
# - target — целевой признак,
# - repeat — количество повторений.
# Функция вернёт признаки и целевой признак после операции upsampling.
#
# Вызовите функцию для обучающих данных. Если всё будет верно, размеры преобразованных выборок появятся на экране.

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 2)

print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (664, 60)
# (664,)

# %%
class_frequency = target_upsampled.value_counts(normalize=True)
print(class_frequency)
# Out:
# 0    0.503012
# 1    0.496988
# Name: g7_member, dtype: float64

# %% [markdown]
# **4**
#
# Обучите на новых данных модель LogisticRegression. Найдите для неё значение F1-меры, и print() выведет её на экран.

# %%
model = LogisticRegression(solver='liblinear')
model.fit(features_upsampled, target_upsampled)
predictions = model.predict(features_test)

print("F1:", f1_score(target_test, predictions))
# Out:
# F1: 0.7586206896551725

# %% [markdown]
# ### Уменьшение выборки

# %% [markdown]
# **1**
#
# Чтобы выполнить downsampling, напишите функцию downsample() с тремя аргументами:
# - features — признаки;
# - target — целевой признак;
# - fraction — доля отрицательных объектов, которые нужно сохранить.
#
# Функция вернёт признаки и целевой признак после операции downsampling. Вызовите функцию для обучающих данных с аргументом fraction, равным 0.1. Код выведет на экран размеры выборок.

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    return features_downsampled, target_downsampled

# %%
features_downsampled, target_downsampled = downsample(features_train, target_train, 0.5)

print(features_downsampled.shape)
print(target_downsampled.shape)
# Out:
# (332, 60)
# (332,)

# %%
class_frequency = target_downsampled.value_counts(normalize=True)
print(class_frequency)
# Out:
# 0    0.503012
# 1    0.496988
# Name: g7_member, dtype: float64

# %% [markdown]
# **2**
#
# Обучите на новых данных модель LogisticRegression. Найдите для неё значение F1-меры, и код выведет его на экран.

# %%
model = LogisticRegression(solver='liblinear')
model.fit(features_downsampled, target_downsampled)
predictions = model.predict(features_test)

print("F1:", f1_score(target_test, predictions))
# Out:
# F1: 0.7671232876712328

# %% [markdown]
# ### Изменение порога

# %% [markdown]
# **1**
#
# Найдите значения вероятностей классов для тестовой выборки. Значения вероятностей класса «1» сохраните в переменной probabilities_one. Напечатайте на экране первые пять элементов этой переменной.

# %%
model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_train, target_train)

probabilities = model.predict_proba(features_test)
probabilities_one = probabilities[:, 1]

print(probabilities_one[:5])
# Out:
# [0.71079132 0.83346019 0.11417186 0.36469921 0.65972379]

# %% [markdown]
# **2**
#
# Переберите значения порогов от 0 до 0.3 с шагом 0.02. Найдите для каждого значения точность и полноту. Напечатайте результаты на экране.
#
# Чтобы создать цикл с нужным диапазоном, мы применили функцию arange() (от англ. «упорядочивать») библиотеки numpy. Как и range(), функция перебирает указанные элементы диапазона, но работает не только с целыми, но и дробными числами.

# %%
model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_train, target_train)
probabilities = model.predict_proba(features_test)
probabilities_one = probabilities[:, 1]

for threshold in np.arange(0, 0.3, 0.02):
    predictions = probabilities_one > threshold
    precision = precision_score(target_test, predictions)
    recall = recall_score(target_test, predictions)

    print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}".format(threshold, precision, recall))
# Out:
# Порог = 0.00 | Точность = 0.313, Полнота = 1.000
# Порог = 0.02 | Точность = 0.412, Полнота = 0.985
# Порог = 0.04 | Точность = 0.418, Полнота = 0.985
# Порог = 0.06 | Точность = 0.437, Полнота = 0.985
# Порог = 0.08 | Точность = 0.452, Полнота = 0.985
# Порог = 0.10 | Точность = 0.465, Полнота = 0.985
# Порог = 0.12 | Точность = 0.468, Полнота = 0.970
# Порог = 0.14 | Точность = 0.485, Полнота = 0.970
# Порог = 0.16 | Точность = 0.492, Полнота = 0.970
# Порог = 0.18 | Точность = 0.520, Полнота = 0.955
# Порог = 0.20 | Точность = 0.557, Полнота = 0.955
# Порог = 0.22 | Точность = 0.578, Полнота = 0.940
# Порог = 0.24 | Точность = 0.592, Полнота = 0.910
# Порог = 0.26 | Точность = 0.616, Полнота = 0.910
# Порог = 0.28 | Точность = 0.638, Полнота = 0.896

# %% [markdown]
# - [x] Вводный ликбез
# - [x] Таблицы: операции с таблицами, pandas, немного pivot, groupby
# - [x] Предобработка данных: удаление пропусков, поиск дубликатов, изменение типов данных.
# - [x] Графики. Гистограмма. Диаграмма размаха. Диаграмма рассеяния.
# - [x] Статистический анализ данных в питоне. Описательная статистика. Двумерный анализ: корреляции, сравнение средних. Стат. проверка.
# - [x] Подготовка к машинному обучению: подвыборки. Стандартизация. OHE.
# - [x] Машинное обучение с учителем: методы регрессии. Простые методы, ансамблевые методы.
# - [x] Машинное обучение с учителем: метрики качества для методов регрессии.
# - [x] Машинное обучение с учителем: методы классификации. Простые методы, ансамблевые методы.
# - [x] Машинное обучение с учителем: метрики качества для методов классификации.
# - [x] Машинное обучение без учителя, или методы кластеризации и снижения размерности
# - [x] Настройка гиперпараметров: кроссвалидация
